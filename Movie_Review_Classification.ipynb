# %%
from keras.datasets import imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/datasets/imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/datasets/imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):  # one-hot encoding
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.  # sequence is a list
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation = 'relu', input_shape = (10000,))) # Hidden Layer1
model.add(layers.Dense(16, activation = 'relu')) # Hidden Layer2
model.add(layers.Dense(1, activation = 'sigmoid')) # Scoring

# %%
from keras import optimizers

model.compile(optimizer='rmsprop',  # set optimizer
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
model.compile(optimizer='rmsprop',
              loss = 'binary_crossentropy',
              metrics=['acc'])

history = model.fit(partial_x_train,  # fit function trains model
                    partial_y_train,
                    epochs = 20,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.5827 - acc: 0.7072 - val_loss: 0.3875 - val_acc: 0.8571
# Epoch 2/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.3180 - acc: 0.9035 - val_loss: 0.3087 - val_acc: 0.8856
# Epoch 3/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.2280 - acc: 0.9264 - val_loss: 0.2761 - val_acc: 0.8911
# Epoch 4/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1730 - acc: 0.9486 - val_loss: 0.2744 - val_acc: 0.8900
# Epoch 5/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1356 - acc: 0.9600 - val_loss: 0.2781 - val_acc: 0.8886
# Epoch 6/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1139 - acc: 0.9674 - val_loss: 0.3603 - val_acc: 0.8608
# Epoch 7/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0994 - acc: 0.9724 - val_loss: 0.3117 - val_acc: 0.8809
# Epoch 8/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0772 - acc: 0.9801 - val_loss: 0.3209 - val_acc: 0.8825
# Epoch 9/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0665 - acc: 0.9842 - val_loss: 0.3569 - val_acc: 0.8800
# Epoch 10/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0529 - acc: 0.9874 - val_loss: 0.3634 - val_acc: 0.8782
# Epoch 11/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0421 - acc: 0.9916 - val_loss: 0.3919 - val_acc: 0.8757
# Epoch 12/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0333 - acc: 0.9939 - val_loss: 0.4140 - val_acc: 0.8778
# Epoch 13/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0279 - acc: 0.9951 - val_loss: 0.4598 - val_acc: 0.8676
# Epoch 14/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0221 - acc: 0.9972 - val_loss: 0.4971 - val_acc: 0.8719
# Epoch 15/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0168 - acc: 0.9982 - val_loss: 0.5406 - val_acc: 0.8688
# Epoch 16/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0146 - acc: 0.9984 - val_loss: 0.5380 - val_acc: 0.8669
# Epoch 17/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0092 - acc: 0.9996 - val_loss: 0.6176 - val_acc: 0.8585
# Epoch 18/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0117 - acc: 0.9986 - val_loss: 0.6026 - val_acc: 0.8667
# Epoch 19/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.0063 - acc: 0.9994 - val_loss: 0.6363 - val_acc: 0.8662
# Epoch 20/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0038 - acc: 0.9999 - val_loss: 0.6738 - val_acc: 0.8665

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label = 'Training loss') # make a graph
plt.plot(epochs, val_loss, 'b', label = 'Validation loss') # make a graph
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc = history_dict['acc']
val_acc = history_dict['val_acc']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend

plt.show()

# %%
print(model.evaluate(x_test,y_test)) #Test
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.7404 - acc: 0.8530
# [0.7403967380523682, 0.8530399799346924]
