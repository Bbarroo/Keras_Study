# %%
# !git config --global user.email "Bbarroo@naver.com"
# !git config --global user.name "Mer9ury"

# %%
cd drive/MyDrive/Keras
# Out:
# /content/drive/MyDrive/Keras

# %%
ls -al
# Out:
# "git.ipynb'"   Keras_Study/   Movie_Review_Classification.ipynb

# %%
# !git config
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/cs231n/.git/

# %%
# !git status
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m "Movie Review Classification finished"
# Out:
# [master c580ea1] Movie Review Classification finished
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite Movie_Review_Classification.ipynb (99%)
#  rewrite git.ipynb' (77%)

# %%
# !git push -u origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 26.28 KiB | 4.38 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Mer9ury/Keras_Study.git
#    377f67f..c580ea1  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git remote rm origin
# !git remote add origin https://Mer9ury:reus3697!@github.com/Mer9ury/Keras_Study.git

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Keras/.git/

# %%
# !git clone https://github.com/Mer9ury/Keras_Study.git
# Out:
# fatal: destination path 'Keras_Study' already exists and is not an empty directory.
