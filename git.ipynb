# %%
# !git config --global user.email "Bbarroo@naver.com"
# !git config --global user.name "Mer9ury"

# %%
cd drive/MyDrive/Keras
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Keras'
# /content/drive/MyDrive/Keras

# %%
ls -al
# Out:
# "git.ipynb'"   Keras_Study/   Movie_Review_Classification.ipynb

# %%
# !git config
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/cs231n/.git/

# %%
# !git status
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m "Movie Review Multi-Class Classification finished"
# Out:
# [master 4207543] Movie Review Multi-Class Classification finished
#  4 files changed, 3 insertions(+), 2 deletions(-)
#  rewrite Movie_Review_Classification.ipynb (86%)
#  create mode 100644 Movie_Review_Multiclass_Classificaiton.ipynb
#  create mode 100644 git.ipynb
#  delete mode 100644 git.ipynb'

# %%
# !git push -u origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 51.15 KiB | 5.68 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/Mer9ury/Keras_Study.git
#    c580ea1..4207543  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git remote rm origin
# !git remote add origin https://Mer9ury:reus3697!@github.com/Mer9ury/Deep_Learning_Study.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# !git clone https://github.com/Mer9ury/Keras_Study.git
# Out:
# fatal: destination path 'Keras_Study' already exists and is not an empty directory.
