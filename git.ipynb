# %%
# !git config --global user.email "bbarroo7425@gmail.com"
# !git config --global user.name "Bbarroo"

# %%
# Out:
# assignments/  git.ipynb

# %%
# !git config
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/cs231n/.git/

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   assignments/assignment1/cs231n/classifiers/linear_svm.py
# 	modified:   assignments/assignment1/knn.ipynb
# 	modified:   assignments/assignment1/svm.ipynb
# 	modified:   git.ipynb

# %%
# !git commit -m "2020.10.09"
# Out:
# [master e05b7ca] 2020.10.09
#  4 files changed, 103 insertions(+), 103 deletions(-)
#  rewrite assignments/assignment1/knn.ipynb (93%)
#  rewrite assignments/assignment1/svm.ipynb (95%)
#  rewrite git.ipynb (94%)

# %%
# !git remote rm origin
# !git remote add origin https://Bbarroo:reus3697!@github.com/Bbarroo/Deep_Learning_Study.git

# %%
# !git push -f origin master
# Out:
# Counting objects: 10, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (10/10), 519.72 KiB | 7.76 MiB/s, done.
# Total 10 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# remote:
# remote: GitHub found 12 vulnerabilities on Bbarroo/Deep_Learning_Study's default branch (2 high, 9 moderate, 1 low). To find out more, visit:
# remote:      https://github.com/Bbarroo/Deep_Learning_Study/network/alerts
# remote:
# To https://github.com/Bbarroo/Deep_Learning_Study.git
#    ca897a1..e05b7ca  master -> master

# %%
# !git add .
